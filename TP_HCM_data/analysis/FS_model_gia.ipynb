# %% [markdown]
# #### Feature Selection — Model GIÁ (bộ TP.HCM)
#
# Mục tiêu: chọn bộ feature tốt nhất để dự đoán `target_shown_price`.
#
# Giá do thuộc tính chuyến đi quyết định: dịch vụ, quãng đường, thời lượng (tắc đường) + lịch sử giá.
#
# Notebook chạy **5 phương pháp** chọn feature, mỗi phương pháp trình bày 4 mục: *phương pháp là gì ·
# cách thực hiện · thực hiện · bảng feature chọn được*. Cuối cùng **đối chiếu** kết quả 5 phương pháp
# để ra bộ feature chốt.
#
# Năm phương pháp: (1) Correlation & η · (2) Mutual Information · (3) Permutation importance ·
# (4) RFE / backward selection · (5) SHAP.

# %% [markdown]
# **Chuẩn bị: nạp dữ liệu, feature ứng viên, mã hoá cho RFE/SHAP**

# %%
import sys; sys.path.insert(0, ".")
from _common import *
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.inspection import permutation_importance
from sklearn.feature_selection import mutual_info_regression, RFE
from sklearn.preprocessing import OrdinalEncoder
setup()
df = load(frac=0.12)   # doi frac=1.0 khi chay that

CAT = ["service_name", "pickup_location_name", "dropoff_location_name", "weather_main"]
NUM = ["quote_distance", "quote_duration", "gio_vn", "thu_vn", "target_is_weekend", "latest_observed_price", "history_60m_price_mean", "history_60m_price_std", "history_60m_price_min", "history_60m_price_max", "history_60m_price_slope_per_minute", "persistence_prediction", "latest_observed_quote_distance", "latest_observed_quote_duration", "requested_lag_minutes", "actual_observation_age_minutes", "weather_temp", "weather_humidity"]
FEATS = CAT + NUM
TARGET = "target_shown_price"
K = 12   # so feature chon o moi phuong phap

# Chong leakage
CAM = {"target_shown_price","target_shown_multiplier","target_price_per_km",
       "split","scenario_id","forecast_example_id","target_request_id","is_synthetic"}
assert not (set(FEATS) & CAM), "CO FEATURE LEAKAGE!"
print(f"Model GIÁ: {len(FEATS)} feature ung vien ({len(CAT)} cat + {len(NUM)} num) | chon top K={K}")

name_vn = "GIA"
def prep(d, cat):
    X=d.copy()
    for c in cat: X[c]=X[c].astype("category")
    return X

# Ma hoa so cho RFE/SHAP (RandomForest can so + khong NaN)
enc = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
Xrf = df[FEATS].copy()
Xrf[CAT] = enc.fit_transform(Xrf[CAT].astype(str))
Xrf = Xrf.fillna(Xrf.median(numeric_only=True))
y = df[TARGET].values

SELECTED = {}   # luu bo feature chon cua tung phuong phap
def bang_chon(rank_series, ten):
    sel = list(rank_series.head(K).index)
    SELECTED[ten] = sel
    print(f"[{ten}] chon {len(sel)} feature:"); print("   " + ", ".join(sel))
    return rank_series.to_frame("diem")
print("San sang.")
# Out:
# Nap 827,693 dong (mau 12%) | gia median 114k VND | surge 81.7%
# Model GIÁ: 22 feature ung vien (4 cat + 18 num) | chon top K=12
# San sang.

# %% [markdown]
# #### 1. Correlation và Correlation ratio (η)
#
# **Phương pháp là gì:** đo quan hệ trực tiếp giữa từng feature với target, không cần train model
# (nhóm *filter*). Nhanh, đơn giản.
#
# **Cách thực hiện:** biến số dùng |Pearson correlation|; biến phân loại dùng η (0–1, % phương sai
# target giải thích bởi nhóm). Xếp hạng, chọn top K.

# %%
# Thuc hien
rows={}
for f in CAT: rows[f]=eta(df[f], df[TARGET])
for f in NUM: rows[f]=abs(df[f].corr(df[TARGET]))
rank_corr = pd.Series(rows).sort_values(ascending=False)
# Ket qua
print("Ket qua — xep hang + feature chon:")
display(bang_chon(rank_corr, "Correlation/eta").round(4))
# Out:
# Ket qua — xep hang + feature chon:
# [Correlation/eta] chon 12 feature:
#    quote_duration, quote_distance, history_60m_price_mean, history_60m_price_min, persistence_prediction, latest_observed_price, history_60m_price_std, history_60m_price_max, latest_observed_quote_distance, latest_observed_quote_duration, pickup_location_name, gio_vn
#                                       diem
# quote_duration                      0.6967
# quote_distance                      0.6891
# history_60m_price_mean              0.6644
# history_60m_price_min               0.6134
# persistence_prediction              0.5035
# latest_observed_price               0.5035
# history_60m_price_std               0.4822
# history_60m_price_max               0.4802
# latest_observed_quote_distance      0.4377
# latest_observed_quote_duration      0.3777
# pickup_location_name                0.2913
# gio_vn                              0.1938
# dropoff_location_name               0.1211
# weather_main                        0.0967
# weather_temp                        0.0772
# target_is_weekend                   0.0767
# weather_humidity                    0.0704
# thu_vn                              0.0672
# actual_observation_age_minutes      0.0483
# service_name                        0.0279
# history_60m_price_slope_per_minute  0.0169
# requested_lag_minutes               0.0004

# %% [markdown]
# #### 2. Mutual Information
#
# **Phương pháp là gì:** đo lượng thông tin feature cung cấp về target — bắt được cả quan hệ **phi
# tuyến** mà correlation bỏ sót (nhóm *filter*).
#
# **Cách thực hiện:** tính MI của từng feature (đã mã hoá số) với target trên một mẫu; xếp hạng, chọn top K.

# %%
# Thuc hien
samp = np.random.RandomState(0).choice(len(Xrf), min(40000,len(Xrf)), replace=False)
mi = mutual_info_regression(Xrf.iloc[samp], y[samp], random_state=0)
rank_mi = pd.Series(mi, index=FEATS).sort_values(ascending=False)
# Ket qua
print("Ket qua — xep hang + feature chon:")
display(bang_chon(rank_mi, "MutualInfo").round(4))
# Out:
# Ket qua — xep hang + feature chon:
# [MutualInfo] chon 12 feature:
#    quote_distance, history_60m_price_mean, quote_duration, history_60m_price_min, history_60m_price_max, persistence_prediction, latest_observed_price, latest_observed_quote_distance, history_60m_price_std, latest_observed_quote_duration, gio_vn, pickup_location_name
#                                       diem
# quote_distance                      0.3787
# history_60m_price_mean              0.3710
# quote_duration                      0.3538
# history_60m_price_min               0.2947
# history_60m_price_max               0.2321
# persistence_prediction              0.2118
# latest_observed_price               0.2082
# latest_observed_quote_distance      0.1977
# history_60m_price_std               0.1943
# latest_observed_quote_duration      0.1215
# gio_vn                              0.0671
# pickup_location_name                0.0573
# actual_observation_age_minutes      0.0405
# weather_humidity                    0.0284
# weather_temp                        0.0251
# history_60m_price_slope_per_minute  0.0242
# dropoff_location_name               0.0148
# service_name                        0.0146
# thu_vn                              0.0087
# weather_main                        0.0044
# target_is_weekend                   0.0044
# requested_lag_minutes               0.0000

# %% [markdown]
# #### 3. Permutation importance
#
# **Phương pháp là gì:** đo feature mà **model thực sự dùng** — xáo trộn ngẫu nhiên 1 feature rồi
# xem sai số tăng bao nhiêu (nhóm *embedded*). Đáng tin vì tính cả tương tác.
#
# **Cách thực hiện:** train HistGradientBoosting trên tập train; trên tập validation, xáo trộn từng
# feature, đo mức tăng sai số; xếp hạng, chọn top K.

# %%
# Thuc hien
tr = df[df.split=="train"].sample(min(60000,(df.split=="train").sum()), random_state=1)
va = df[df.split=="validation"].sample(min(20000,(df.split=="validation").sum()), random_state=2)
m = HistGradientBoostingRegressor(max_iter=200, learning_rate=0.08, categorical_features=CAT,
    random_state=42).fit(prep(tr,CAT)[FEATS], tr[TARGET])
pi = permutation_importance(m, prep(va,CAT)[FEATS], va[TARGET], n_repeats=3, random_state=0, n_jobs=1)
rank_perm = pd.Series(pi.importances_mean, index=FEATS).sort_values(ascending=False)
# Ket qua
print("Ket qua — xep hang + feature chon:")
display(bang_chon(rank_perm, "Permutation").round(4))
# Out:
# Ket qua — xep hang + feature chon:
# [Permutation] chon 12 feature:
#    quote_distance, quote_duration, history_60m_price_mean, gio_vn, thu_vn, latest_observed_quote_distance, weather_main, dropoff_location_name, latest_observed_price, pickup_location_name, history_60m_price_min, history_60m_price_slope_per_minute
#                                       diem
# quote_distance                      0.2881
# quote_duration                      0.2212
# history_60m_price_mean              0.1186
# gio_vn                              0.0735
# thu_vn                              0.0121
# latest_observed_quote_distance      0.0104
# weather_main                        0.0064
# dropoff_location_name               0.0054
# latest_observed_price               0.0030
# pickup_location_name                0.0020
# history_60m_price_min               0.0017
# history_60m_price_slope_per_minute  0.0005
# history_60m_price_std               0.0005
# weather_temp                        0.0003
# target_is_weekend                   0.0003
# service_name                        0.0002
# history_60m_price_max               0.0001
# actual_observation_age_minutes      0.0001
# requested_lag_minutes               0.0000
# persistence_prediction              0.0000
# weather_humidity                   -0.0001
# latest_observed_quote_duration     -0.0001

# %% [markdown]
# #### 4. RFE — Recursive Feature Elimination (backward selection)
#
# **Phương pháp là gì:** chọn feature theo kiểu *wrapper* — bắt đầu với **tất cả** feature, **loại
# dần** feature yếu nhất, train lại, lặp đến khi còn K feature. Đây chính là *backward selection*.
#
# **Cách thực hiện:** dùng RandomForest (có `feature_importances_`) làm bộ đánh giá; RFE loại 2
# feature mỗi vòng cho tới khi còn K. Feature còn lại là bộ được chọn.

# %%
# Thuc hien (RandomForest can so -> dung Xrf da ma hoa)
s = np.random.RandomState(3).choice(len(Xrf), min(25000,len(Xrf)), replace=False)
rf = RandomForestRegressor(n_estimators=60, max_depth=14, n_jobs=-1, random_state=42)
rfe = RFE(rf, n_features_to_select=K, step=2).fit(Xrf.iloc[s], y[s])
rank_rfe = pd.Series(rfe.ranking_, index=FEATS).sort_values()   # 1 = duoc chon
SELECTED["RFE"] = [f for f,keep in zip(FEATS, rfe.support_) if keep]
# Ket qua
print(f"[RFE] chon {len(SELECTED['RFE'])} feature:"); print("   " + ", ".join(SELECTED["RFE"]))
print("\n(ranking: 1 = duoc chon, so cang lon = bi loai cang som)")
display(rank_rfe.to_frame("ranking"))
# Out:
# [RFE] chon 12 feature:
#    quote_distance, quote_duration, gio_vn, history_60m_price_mean, history_60m_price_std, history_60m_price_min, history_60m_price_slope_per_minute, persistence_prediction, latest_observed_quote_distance, latest_observed_quote_duration, actual_observation_age_minutes, weather_humidity
#
# (ranking: 1 = duoc chon, so cang lon = bi loai cang som)
#                                     ranking
# quote_duration                            1
# gio_vn                                    1
# quote_distance                            1
# persistence_prediction                    1
# history_60m_price_min                     1
# history_60m_price_slope_per_minute        1
# history_60m_price_mean                    1
# history_60m_price_std                     1
# weather_humidity                          1
# actual_observation_age_minutes            1
# latest_observed_quote_duration            1
# latest_observed_quote_distance            1
# history_60m_price_max                     2
# weather_temp                              2
# latest_observed_price                     3
# thu_vn                                    3
# dropoff_location_name                     4
# weather_main                              4
# service_name                              5
# pickup_location_name                      5
# target_is_weekend                         6
# requested_lag_minutes                     6

# %% [markdown]
# #### 5. SHAP
#
# **Phương pháp là gì:** đo đóng góp của từng feature vào **từng dự đoán** (dựa trên lý thuyết trò
# chơi Shapley), rồi lấy trung bình |đóng góp| làm mức quan trọng. Diễn giải sâu, có chiều (nhóm *embedded*).
#
# **Cách thực hiện:** train RandomForest, dùng `TreeExplainer` tính SHAP values trên một mẫu nhỏ;
# lấy mean(|SHAP|) mỗi feature; xếp hạng, chọn top K.

# %%
# Thuc hien
try:
    import shap
    s2 = np.random.RandomState(5).choice(len(Xrf), min(20000,len(Xrf)), replace=False)
    rf2 = RandomForestRegressor(n_estimators=60, max_depth=14, n_jobs=-1, random_state=42).fit(Xrf.iloc[s2], y[s2])
    Xs = Xrf.iloc[np.random.RandomState(6).choice(len(Xrf), 1500, replace=False)]
    sv = shap.TreeExplainer(rf2).shap_values(Xs)
    rank_shap = pd.Series(np.abs(sv).mean(0), index=FEATS).sort_values(ascending=False)
    print("Ket qua — xep hang + feature chon:")
    display(bang_chon(rank_shap, "SHAP").round(4))
except ImportError:
    print("Chua cai shap. Chay: pip install shap")
    SELECTED["SHAP"] = []
# Out:
# Ket qua — xep hang + feature chon:
# [SHAP] chon 12 feature:
#    quote_distance, quote_duration, history_60m_price_mean, gio_vn, latest_observed_quote_distance, history_60m_price_min, thu_vn, weather_main, weather_temp, history_60m_price_slope_per_minute, persistence_prediction, history_60m_price_max
#                                           diem
# quote_distance                      17346.1167
# quote_duration                      11695.5585
# history_60m_price_mean               9197.4194
# gio_vn                               5175.5972
# latest_observed_quote_distance       1077.3598
# history_60m_price_min                1031.8323
# thu_vn                                832.5850
# weather_main                          720.3409
# weather_temp                          560.9863
# history_60m_price_slope_per_minute    546.4922
# persistence_prediction                443.5583
# history_60m_price_max                 433.2216
# weather_humidity                      430.5076
# history_60m_price_std                 412.4798
# latest_observed_price                 408.6879
# latest_observed_quote_duration        338.3506
# actual_observation_age_minutes        327.5848
# dropoff_location_name                 201.4471
# target_is_weekend                     200.8685
# pickup_location_name                   99.3736
# service_name                           81.9756
# requested_lag_minutes                  51.0976

# %% [markdown]
# #### Kiểm tra trùng lặp (bổ trợ)
#
# Hai feature |r| > 0,9 mang thông tin trùng → nên bỏ bớt 1 (model gọn, importance không chia phiếu).

# %%
import itertools
corr = df[NUM].corr().abs()
trung=[(a,b,round(corr.loc[a,b],3)) for a,b in itertools.combinations(NUM,2) if corr.loc[a,b]>0.9]
if trung:
    print("Cap feature TRUNG LAP (|r|>0.9) -> can nhac bo bot 1:")
    for a,b,r in sorted(trung,key=lambda x:-x[2]): print(f"   {a:36} <-> {b:36} r={r}")
else:
    print("Khong co cap |r|>0.9.")
# Out:
# Cap feature TRUNG LAP (|r|>0.9) -> can nhac bo bot 1:
#    latest_observed_price                <-> persistence_prediction               r=1.0
#    requested_lag_minutes                <-> actual_observation_age_minutes       r=0.972
#    history_60m_price_std                <-> history_60m_price_max                r=0.929
#    weather_temp                         <-> weather_humidity                     r=0.924
#    history_60m_price_mean               <-> history_60m_price_min                r=0.916

# %% [markdown]
# #### Đối chiếu 5 phương pháp và chốt bộ feature
#
# Đếm mỗi feature được **bao nhiêu phương pháp chọn** (bỏ phiếu). Feature được **nhiều phương pháp
# đồng thuận** thì càng đáng giữ. Bộ chốt = feature được ≥ 3/5 phương pháp chọn (kết hợp loại trùng lặp).

# %%
# Bang doi chieu: moi feature x moi phuong phap (1 = duoc chon)
pps = ["Correlation/eta","MutualInfo","Permutation","RFE","SHAP"]
dc = pd.DataFrame(0, index=FEATS, columns=pps)
for pp in pps:
    for f in SELECTED.get(pp,[]): dc.loc[f,pp]=1
dc["so_pp_chon"] = dc.sum(axis=1)
dc = dc.sort_values("so_pp_chon", ascending=False)
print("BANG DOI CHIEU 5 PHUONG PHAP (1 = duoc chon):")
display(dc)
# Out:
# BANG DOI CHIEU 5 PHUONG PHAP (1 = duoc chon):
#                                     Correlation/eta  MutualInfo  Permutation  RFE  SHAP  so_pp_chon
# quote_distance                                    1           1            1    1     1           5
# quote_duration                                    1           1            1    1     1           5
# latest_observed_quote_distance                    1           1            1    1     1           5
# history_60m_price_min                             1           1            1    1     1           5
# history_60m_price_mean                            1           1            1    1     1           5
# gio_vn                                            1           1            1    1     1           5
# persistence_prediction                            1           1            0    1     1           4
# latest_observed_quote_duration                    1           1            0    1     0           3
# history_60m_price_std                             1           1            0    1     0           3
# pickup_location_name                              1           1            1    0     0           3
# history_60m_price_slope_per_minute                0           0            1    1     1           3
# history_60m_price_max                             1           1            0    0     1           3
# latest_observed_price                             1           1            1    0     0           3
# weather_main                                      0           0            1    0     1           2
# thu_vn                                            0           0            1    0     1           2
# dropoff_location_name                             0           0            1    0     0           1
# weather_humidity                                  0           0            0    1     0           1
# actual_observation_age_minutes                    0           0            0    1     0           1
# weather_temp                                      0           0            0    0     1           1
# service_name                                      0           0            0    0     0           0
# target_is_weekend                                 0           0            0    0     0           0
# requested_lag_minutes                             0           0            0    0     0           0

# %%
# Bo feature CHOT: duoc >= 3/5 phuong phap chon
chot = list(dc[dc.so_pp_chon >= 3].index)
chot_cat = [f for f in chot if f in CAT]
chot_num = [f for f in chot if f in NUM]
print("="*60)
print(f"BO FEATURE CHOT — MODEL {name_vn} (>= 3/5 phuong phap dong thuan)")
print("="*60)
print(f"  Categorical ({len(chot_cat)}): {chot_cat}")
print(f"  Numeric     ({len(chot_num)}): {chot_num}")
print(f"  Tong: {len(chot)} feature  |  Target: {TARGET}")
print("\n  (Co the chinh tay: bo bot cap trung lap o buoc tren neu con)")
# Out:
# ============================================================
# BO FEATURE CHOT — MODEL GIA (>= 3/5 phuong phap dong thuan)
# ============================================================
#   Categorical (1): ['pickup_location_name']
#   Numeric     (12): ['quote_distance', 'quote_duration', 'latest_observed_quote_distance', 'history_60m_price_min', 'history_60m_price_mean', 'gio_vn', 'persistence_prediction', 'latest_observed_quote_duration', 'history_60m_price_std', 'history_60m_price_slope_per_minute', 'history_60m_price_max', 'latest_observed_price']
#   Tong: 13 feature  |  Target: target_shown_price
#
#   (Co the chinh tay: bo bot cap trung lap o buoc tren neu con)
